# %%
# %reload_ext autoreload
# %autoreload 2

import sys

sys.path.append("/Users/henrydashwood/Documents/housing_prices")

# %%
from src.datasets.us import cbp_dataset, saiz_dataset, us_geography_dataset

# %%
# Download CBP employment data
cbp_dataset.download(years=[2021])

# Download geographic crosswalk
us_geography_dataset.download()

# Create Saiz data files (with download instructions)
saiz_dataset.download()
# Out:
# ...
#   2021: Downloading from https://www2.census.gov/programs-surveys/cbp/datasets/2021/cbp21co.zip
#   2021: Saved to /Users/henrydashwood/Documents/housing_prices/data/raw/us/cbp/cbp21co.zip
# ...
#   Failed to download CBSA file: 404 Client Error: Not Found for url: https://www2.census.gov/programs-surveys/metro-micro/geographies/reference-files/2023/delineation-files/list1_2023.xls
#   Manual download: https://www2.census.gov/programs-surveys/metro-micro/geographies/reference-files/2023/delineation-files/list1_2023.xls
# ...
#   Saved: /Users/henrydashwood/Documents/housing_prices/data/raw/us/geography/county_fips_2020.txt
# Created download instructions at: /Users/henrydashwood/Documents/housing_prices/data/raw/us/saiz/DOWNLOAD_INSTRUCTIONS.md
# Created fallback data with 19 key MSAs: /Users/henrydashwood/Documents/housing_prices/data/raw/us/saiz/saiz_elasticities_key_msas.csv
# PosixPath('/Users/henrydashwood/Documents/housing_prices/data/raw/us/saiz')
